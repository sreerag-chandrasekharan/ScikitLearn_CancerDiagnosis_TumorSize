# %% [markdown]
# ## Tumer detection

# %%
import numpy as np
import matplotlib.pyplot as plt
from functions import*
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Data set

# %%
X_train, y_train = load_data()
X_features = ['Radious', 'Cancer state']

# %%
# Reshape
X_train = X_train.reshape(-1, 1)
y_train = y_train

# %%
fig,ax = plt.subplots(1,1,figsize=(14,4))
plot_data(X_train, y_train, ax)

# %% [markdown]
# ## The MOdel

# %%
lr_model = LogisticRegression()

# %% [markdown]
# ### Traning of data

# %%
lr_model.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Test Model

# %%
y_pred = lr_model.predict(X_train)

# %%
fig,ax = plt.subplots(1,1,figsize=(14,4))
plot_with_predictions(X_train, y_train, y_pred, ax)

# %% [markdown]
# ##### Accuracy

# %%
# Calculate the accuracy on the training set
accuracy = lr_model.score(X_train, y_pred) * 100

# Print the accuracy as a percentage
print(f"Accuracy on training set: {accuracy:.2f}%")
# Out:
# Accuracy on training set: 100.00%

# %% [markdown]
# ### Evalvation

# %%
Size_12 = lr_model.predict([[12.88],[16.01]])

# %%
print(Size_12)
# Out:
# [0. 1.]

# %% [markdown]
# ## Done.
